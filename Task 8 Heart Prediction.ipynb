# %% [markdown]
# # Task 8
# # Referral ID: SIRSS2150
# # Name : Arpit Sharma

# %% [markdown]
# Heart Attack Analysis & Prediction
#
#
# - Analysis & Predict Heart Attack based on Age, Gender, No. of disease they have and some other aspects
#
# Description: https://www.kaggle.com/rashikrahmanpritom/heart-attack-analysis-prediction-dataset/tasks?taskId=3833

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('heart.csv')
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
df.tail()
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 298    0      3       0
# 299    0      3       0
# 300    2      3       0
# 301    1      3       0
# 302    1      2       0

# %%
df.shape
# Out:
# (303, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %%
df.describe()
# Out:
#              age         sex          cp      trtbps        chol         fbs  \
# count  302.00000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.42053    0.682119    0.963576  131.602649  246.500000    0.149007
# std      9.04797    0.466426    1.032044   17.563394   51.753489    0.356686
# min     29.00000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.00000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.50000    1.000000    1.000000  130.000000  240.500000    0.000000
# 75%     61.00000    1.000000    2.000000  140.000000  274.750000    0.000000
# max     77.00000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean     0.526490  149.569536    0.327815    1.043046    1.397351    0.718543
# ...

# %% [markdown]
# # Data Visulization

# %%
df.hist(bins=50,figsize=(18,18))
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.barplot(df['age'],df['output'])
plt.title('Distribution of Age w.r.t. Heart Attack ')
plt.show()

# %%
plt.figure(figsize=(7,6))
sns.countplot(df['output'],hue=df['sex'])
plt.title('Distribution of Sex w.r.t. Heart Attack')
plt.show()

# %%
plt.figure(figsize=(7,6))
sns.barplot(df['cp'],df['output'])
plt.title('Distribution of Chest Pain w.r.t. Heart Attack ')
plt.show()

# %%
plt.figure(figsize=(7,6))
sns.countplot(df['restecg'],hue= df['output'])
plt.title('Distribution of  resting electrocardiographic results w.r.t. Heart Attack ')
plt.show()

# %%
plt.figure(figsize=(7,6))
sns.countplot(df['exng'],hue=df['output'])
plt.title('Distribution of exercise induced angina w.r.t. Heart Attack ')
plt.show()

# %%
plt.figure(figsize=(7,6))
sns.barplot(df['caa'],df['output'])
plt.title('Distribution of number of major vessels w.r.t. Heart Attack ')
plt.show()

# %%
plt.figure(figsize=(7,6))
sns.barplot(df['fbs'],df['output'])
plt.title('Distribution of fasting blood sugar w.r.t. Heart Attack ')
plt.show()

# %%
plt.figure(figsize=(7,6))
sns.barplot(df['fbs'],df['output'],hue=df['sex'])
plt.title('Distribution of fasting blood sugar w.r.t. Heart Attack ')
plt.show()

# %%
plt.figure(figsize=(7,6))
sns.lineplot(df['oldpeak'],df['chol'],hue=df['output'])
plt.title('Distribution of oldpeak w.r.t. Heart Attack ')
plt.show()

# %%
plt.figure(figsize=(7,6))
sns.lineplot(df['thalachh'],df['trtbps'],hue=df['output'])
plt.title('Distribution of thalachh w.r.t trtbps')
plt.show()

# %%
plt.figure(figsize=(7,6))
sns.lineplot(df['age'],df['chol'],hue=df['output'])
plt.title('Distribution of Age w.r.t Cholestrol')
plt.show()

# %%
plt.figure(figsize=(7,6))
sns.lineplot(df['age'],df['trtbps'],hue=df['output'])
plt.title('Distribution of Age w.r.t blood pressure')
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot=True)

# %% [markdown]
# # Train-Test split

# %%
X = df.drop('output',axis=1)
Y = df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(X,Y,test_size=.2,random_state=5)

# %%
print("Shape of xtrain: ",xtrain.shape)
print("Shape of xtest: ", xtest.shape)
print("Shape of ytrain: ",ytrain.shape)
print("Shape of ytest: ", ytest.shape)
# Out:
# Shape of xtrain:  (241, 13)
# Shape of xtest:  (61, 13)
# Shape of ytrain:  (241,)
# Shape of ytest:  (61,)

# %% [markdown]
# # Building Model

# %%
from sklearn.linear_model import LogisticRegression
log = LogisticRegression()
log.fit(xtrain,ytrain)
# Out:
# C:\Users\Master\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression()

# %%
ypred= log.predict(xtest)

# %%
log.score(xtrain,ytrain)
# Out:
# 0.8423236514522822

# %%
log.score(xtest,ytest)
# Out:
# 0.819672131147541
